# %%
from FFTMA import *
import seaborn as sns
import matplotlib.pyplot as plt
import skgstat as skg

# %%
m = 500
n = 500
range_h = 20
range_v = 20
err = 1
model = 3

# %%
output = fftma_l3c(m,n, range_h, range_v,err,model)

# %%
####plot
plt.figure(figsize=(20,8))
plt.subplot(121)
sns.heatmap(output,cmap="YlGnBu")
plt.title('Field Simulation')

#histogram
plt.subplot(122)
plt.hist(output.reshape(m*n), bins=150)
plt.title('Field Simulation: Histogram')

plt.show()
# Out:
# C:\Users\rafa\AppData\Local\Temp\2/ipykernel_6048/4083629983.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
values = output.reshape(m*n)
coordinates = np.arange(0,m*m)

Vario = skg.Variogram(coordinates, values,n_lags=25,maxlag=60,plot=False)
Vario.plot()
plt.title('Field Simulation: Variogram')
fig.show()
# Out:
# C:\Users\rafa\anaconda3\envs\datawerk\lib\site-packages\skgstat\plotting\variogram_plot.py:123: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\2/ipykernel_6048/34026009.py in <module>
#       5 Vario.plot()
#       6 plt.title('Field Simulation: Variogram')
# ----> 7 fig.show()
#
# NameError: name 'fig' is not defined
